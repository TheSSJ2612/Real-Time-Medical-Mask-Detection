# %% [markdown]
# Go to directory of project

# %%
# !cd C:\Users\madan\Projects\SummerTraining\Project\Medical_Mask_Detection

# %% [markdown]
# Confirm Directory

# %%
pwd
# Out:
# 'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection'

# %% [markdown]
# Import all modules required for project

# %%
import os
import sys
import tensorflow as tf
import cv2
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import re
import datetime
import seaborn as sn

from IPython.display import Image

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from imutils.video import VideoStream

import imutils
import time

# %matplotlib inline 

# Load tensorboard notebook extension
# %load_ext tensorboard

# %% [markdown]
# # Training Mask Classifier

# %% [markdown]
# Set path for Root Directory and Dataset path for training

# %%
dataset = input("Enter relative path for dataset: ") or "Dataset"
# Out:
# Enter relative path for dataset:

# %%
# Root directory of the project
ROOT_DIR = os.getcwd()
print(ROOT_DIR)
DATASET_DIR = os.path.join(ROOT_DIR, dataset)
sys.path.append(ROOT_DIR)
# Out:
# C:\Users\madan\Projects\SummerTraining\Project\Medical_Mask_Detection

# %% [markdown]
# Hyper-parameters for training mask classifier

# %%
LR = 1e-4
EPOCHS = 30
BATCH_SIZE = 32
IMAGE_SIZE = 224

# %% [markdown]
# Define function to get file names in lexicographical order

# %%
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)

# %% [markdown]
# Define classes for training mask classifier

# %%
classes = ['with_mask', 'without_mask']

# %% [markdown]
# Storing image names along with their classes in a list

# %%
with_mask_names = sorted_alphanumeric(os.listdir(os.path.join(DATASET_DIR, 'with_mask')))
with_mask_names = ['with_mask_'+with_mask_name.split('.')[0] for with_mask_name in with_mask_names]

without_mask_names = sorted_alphanumeric(os.listdir(os.path.join(DATASET_DIR, 'without_mask')))
without_mask_names = ['without_mask_'+without_mask_name.split('.')[0] for without_mask_name in without_mask_names]

# %%
all_image_names = with_mask_names + without_mask_names
all_image_names
# Out:
# ['with_mask_0',
#  'with_mask_1',
#  'with_mask_2',
#  'with_mask_3',
#  'with_mask_4',
#  'with_mask_5',
#  'with_mask_6',
#  'with_mask_7',
#  'with_mask_8',
#  'with_mask_9',
#  'with_mask_10',
#  'with_mask_11',
#  'with_mask_12',
#  'with_mask_13',
#  'with_mask_14',
#  'with_mask_15',
#  'with_mask_16',
#  'with_mask_17',
#  'with_mask_18',
#  'with_mask_19',
#  'with_mask_20',
#  'with_mask_21',
#  'with_mask_22',
#  'with_mask_23',
#  'with_mask_24',
#  'with_mask_25',
#  'with_mask_26',
#  'with_mask_27',
#  'with_mask_28',
#  'with_mask_29',
#  'with_mask_30',
#  'with_mask_31',
#  'with_mask_32',
#  'with_mask_33',
#  'with_mask_34',
#  'with_mask_35',
#  'with_mask_36',
#  'with_mask_37',
#  'with_mask_38',
#  'with_mask_39',
#  'with_mask_40',
#  'with_mask_41',
#  'with_mask_42',
#  'with_mask_43',
#  'with_mask_44',
#  'with_mask_45',
#  'with_mask_46',
#  'with_mask_47',
#  'with_mask_48',
#  'with_mask_49',
#  'with_mask_50',
#  'with_mask_51',
#  'with_mask_52',
#  'with_mask_53',
#  'with_mask_54',
#  'with_mask_55',
#  'with_mask_56',
#  'with_mask_57',
#  'with_mask_58',
#  'with_mask_59',
#  'with_mask_60',
#  'with_mask_61',
#  'with_mask_62',
#  'with_mask_63',
#  'with_mask_64',
#  'with_mask_65',
#  'with_mask_66',
#  'with_mask_67',
#  'with_mask_68',
#  'with_mask_69',
#  'with_mask_70',
#  'with_mask_71',
#  'with_mask_72',
#  'with_mask_73',
#  'with_mask_74',
#  'with_mask_75',
#  'with_mask_76',
#  'with_mask_77',
#  'with_mask_78',
#  'with_mask_79',
#  'with_mask_80',
#  'with_mask_81',
#  'with_mask_82',
#  'with_mask_83',
#  'with_mask_84',
#  'with_mask_85',
#  'with_mask_86',
#  'with_mask_87',
#  'with_mask_88',
#  'with_mask_89',
#  'with_mask_90',
#  'with_mask_91',
#  'with_mask_92',
#  'with_mask_93',
#  'with_mask_94',
#  'with_mask_95',
#  'with_mask_96',
#  'with_mask_97',
#  'with_mask_98',
#  'with_mask_99',
#  'with_mask_100',
#  'with_mask_101',
#  'with_mask_102',
#  'with_mask_103',
#  'with_mask_104',
#  'with_mask_105',
#  'with_mask_106',
#  'with_mask_107',
#  'with_mask_108',
#  'with_mask_109',
#  'with_mask_110',
#  'with_mask_111',
#  'with_mask_112',
#  'with_mask_113',
#  'with_mask_114',
#  'with_mask_115',
#  'with_mask_116',
#  'with_mask_117',
#  'with_mask_118',
#  'with_mask_119',
#  'with_mask_120',
#  'with_mask_121',
#  'with_mask_122',
#  'with_mask_123',
#  'with_mask_124',
#  'with_mask_125',
#  'with_mask_126',
#  'with_mask_127',
#  'with_mask_128',
#  'with_mask_129',
#  'with_mask_130',
#  'with_mask_131',
#  'with_mask_132',
#  'with_mask_133',
#  'with_mask_134',
#  'with_mask_135',
#  'with_mask_136',
#  'with_mask_137',
#  'with_mask_138',
#  'with_mask_139',
#  'with_mask_140',
#  'with_mask_141',
#  'with_mask_142',
#  'with_mask_143',
#  'with_mask_144',
#  'with_mask_145',
#  'with_mask_146',
#  'with_mask_147',
#  'with_mask_148',
#  'with_mask_149',
#  'with_mask_150',
#  'with_mask_151',
#  'with_mask_152',
#  'with_mask_153',
#  'with_mask_154',
#  'with_mask_155',
#  'with_mask_156',
#  'with_mask_157',
#  'with_mask_158',
#  'with_mask_159',
#  'with_mask_160',
#  'with_mask_161',
#  'with_mask_162',
#  'with_mask_163',
#  'with_mask_164',
#  'with_mask_165',
#  'with_mask_166',
#  'with_mask_167',
#  'with_mask_168',
#  'with_mask_169',
#  'with_mask_170',
#  'with_mask_171',
#  'with_mask_172',
#  'with_mask_173',
#  'with_mask_174',
#  'with_mask_175',
#  'with_mask_176',
#  'with_mask_177',
#  'with_mask_178',
#  'with_mask_179',
#  'with_mask_180',
#  'with_mask_181',
#  'with_mask_182',
#  'with_mask_183',
#  'with_mask_184',
#  'with_mask_185',
#  'with_mask_186',
#  'with_mask_187',
#  'with_mask_188',
#  'with_mask_189',
#  'with_mask_190',
#  'with_mask_191',
#  'with_mask_192',
#  'with_mask_193',
#  'with_mask_194',
#  'with_mask_195',
#  'with_mask_196',
#  'with_mask_197',
#  'with_mask_198',
#  'with_mask_199',
#  'with_mask_200',
#  'with_mask_201',
#  'with_mask_202',
#  'with_mask_203',
#  'with_mask_204',
#  'with_mask_205',
#  'with_mask_206',
#  'with_mask_207',
#  'with_mask_208',
#  'with_mask_209',
#  'with_mask_210',
#  'with_mask_211',
#  'with_mask_212',
#  'with_mask_213',
#  'with_mask_214',
#  'with_mask_215',
#  'with_mask_216',
#  'with_mask_217',
#  'with_mask_218',
#  'with_mask_219',
#  'with_mask_220',
#  'with_mask_221',
#  'with_mask_222',
#  'with_mask_223',
#  'with_mask_224',
#  'with_mask_225',
#  'with_mask_226',
#  'with_mask_227',
#  'with_mask_228',
#  'with_mask_229',
#  'with_mask_230',
#  'with_mask_231',
#  'with_mask_232',
#  'with_mask_233',
#  'with_mask_234',
#  'with_mask_235',
#  'with_mask_236',
#  'with_mask_237',
#  'with_mask_238',
#  'with_mask_239',
#  'with_mask_240',
#  'with_mask_241',
#  'with_mask_242',
#  'with_mask_243',
#  'with_mask_244',
#  'with_mask_245',
#  'with_mask_246',
#  'with_mask_247',
#  'with_mask_248',
#  'with_mask_249',
#  'with_mask_250',
#  'with_mask_251',
#  'with_mask_252',
#  'with_mask_253',
#  'with_mask_254',
#  'with_mask_255',
#  'with_mask_256',
#  'with_mask_257',
#  'with_mask_258',
#  'with_mask_259',
#  'with_mask_260',
#  'with_mask_261',
#  'with_mask_262',
#  'with_mask_263',
#  'with_mask_264',
#  'with_mask_265',
#  'with_mask_266',
#  'with_mask_267',
#  'with_mask_268',
#  'with_mask_269',
#  'with_mask_270',
#  'with_mask_271',
#  'with_mask_272',
#  'with_mask_273',
#  'with_mask_274',
#  'with_mask_275',
#  'with_mask_276',
#  'with_mask_277',
#  'with_mask_278',
#  'with_mask_279',
#  'with_mask_280',
#  'with_mask_281',
#  'with_mask_282',
#  'with_mask_283',
#  'with_mask_284',
#  'with_mask_285',
#  'with_mask_286',
#  'with_mask_287',
#  'with_mask_288',
#  'with_mask_289',
#  'with_mask_290',
#  'with_mask_291',
#  'with_mask_292',
#  'with_mask_293',
#  'with_mask_294',
#  'with_mask_295',
#  'with_mask_296',
#  'with_mask_297',
#  'with_mask_298',
#  'with_mask_299',
#  'with_mask_300',
#  'with_mask_301',
#  'with_mask_302',
#  'with_mask_303',
#  'with_mask_304',
#  'with_mask_305',
#  'with_mask_306',
#  'with_mask_307',
#  'with_mask_308',
#  'with_mask_309',
#  'with_mask_310',
#  'with_mask_311',
#  'with_mask_312',
#  'with_mask_313',
#  'with_mask_314',
#  'with_mask_315',
#  'with_mask_316',
#  'with_mask_317',
#  'with_mask_318',
#  'with_mask_319',
#  'with_mask_320',
#  'with_mask_321',
#  'with_mask_322',
#  'with_mask_323',
#  'with_mask_324',
#  'with_mask_325',
#  'with_mask_326',
#  'with_mask_327',
#  'with_mask_328',
#  'with_mask_329',
#  'with_mask_330',
#  'with_mask_331',
#  'with_mask_332',
#  'with_mask_333',
#  'with_mask_334',
#  'with_mask_335',
#  'with_mask_336',
#  'with_mask_337',
#  'with_mask_338',
#  'with_mask_339',
#  'with_mask_340',
#  'with_mask_341',
#  'with_mask_342',
#  'with_mask_343',
#  'with_mask_344',
#  'with_mask_345',
#  'with_mask_346',
#  'with_mask_347',
#  'with_mask_348',
#  'with_mask_349',
#  'with_mask_350',
#  'with_mask_351',
#  'with_mask_352',
#  'with_mask_353',
#  'with_mask_354',
#  'with_mask_355',
#  'with_mask_356',
#  'with_mask_357',
#  'with_mask_358',
#  'with_mask_359',
#  'with_mask_360',
#  'with_mask_361',
#  'with_mask_362',
#  'with_mask_363',
#  'with_mask_364',
#  'with_mask_365',
#  'with_mask_366',
#  'with_mask_367',
#  'with_mask_368',
#  'with_mask_369',
#  'with_mask_370',
#  'with_mask_371',
#  'with_mask_372',
#  'with_mask_373',
#  'with_mask_374',
#  'with_mask_375',
#  'with_mask_376',
#  'with_mask_377',
#  'with_mask_378',
#  'with_mask_379',
#  'with_mask_380',
#  'with_mask_381',
#  'with_mask_382',
#  'with_mask_383',
#  'with_mask_384',
#  'with_mask_385',
#  'with_mask_386',
#  'with_mask_387',
#  'with_mask_388',
#  'with_mask_389',
#  'with_mask_390',
#  'with_mask_391',
#  'with_mask_392',
#  'with_mask_393',
#  'with_mask_394',
#  'with_mask_395',
#  'with_mask_396',
#  'with_mask_397',
#  'with_mask_398',
#  'with_mask_399',
#  'with_mask_400',
#  'with_mask_401',
#  'with_mask_402',
#  'with_mask_403',
#  'with_mask_404',
#  'with_mask_405',
#  'with_mask_406',
#  'with_mask_407',
#  'with_mask_408',
#  'with_mask_409',
#  'with_mask_410',
#  'with_mask_411',
#  'with_mask_412',
#  'with_mask_413',
#  'with_mask_414',
#  'with_mask_415',
#  'with_mask_416',
#  'with_mask_417',
#  'with_mask_418',
#  'with_mask_419',
#  'with_mask_420',
#  'with_mask_421',
#  'with_mask_422',
#  'with_mask_423',
#  'with_mask_424',
#  'with_mask_425',
#  'with_mask_426',
#  'with_mask_427',
#  'with_mask_428',
#  'with_mask_429',
#  'with_mask_430',
#  'with_mask_431',
#  'with_mask_432',
#  'with_mask_433',
#  'with_mask_434',
#  'with_mask_435',
#  'with_mask_436',
#  'with_mask_437',
#  'with_mask_438',
#  'with_mask_439',
#  'with_mask_440',
#  'with_mask_441',
#  'with_mask_442',
#  'with_mask_443',
#  'with_mask_444',
#  'with_mask_445',
#  'with_mask_446',
#  'with_mask_447',
#  'with_mask_448',
#  'with_mask_449',
#  'with_mask_450',
#  'with_mask_451',
#  'with_mask_452',
#  'with_mask_453',
#  'with_mask_454',
#  'with_mask_455',
#  'with_mask_456',
#  'with_mask_457',
#  'with_mask_458',
#  'with_mask_459',
#  'with_mask_460',
#  'with_mask_461',
#  'with_mask_462',
#  'with_mask_463',
#  'with_mask_464',
#  'with_mask_465',
#  'with_mask_466',
#  'with_mask_467',
#  'with_mask_468',
#  'with_mask_469',
#  'with_mask_470',
#  'with_mask_471',
#  'with_mask_472',
#  'with_mask_473',
#  'with_mask_474',
#  'with_mask_475',
#  'with_mask_476',
#  'with_mask_477',
#  'with_mask_478',
#  'with_mask_479',
#  'with_mask_480',
#  'with_mask_481',
#  'with_mask_482',
#  'with_mask_483',
#  'with_mask_484',
#  'with_mask_485',
#  'with_mask_486',
#  'with_mask_487',
#  'with_mask_488',
#  'with_mask_489',
#  'with_mask_490',
#  'with_mask_491',
#  'with_mask_492',
#  'with_mask_493',
#  'with_mask_494',
#  'with_mask_495',
#  'with_mask_496',
#  'with_mask_497',
#  'with_mask_498',
#  'with_mask_499',
#  'with_mask_500',
#  'with_mask_501',
#  'with_mask_502',
#  'with_mask_503',
#  'with_mask_504',
#  'with_mask_505',
#  'with_mask_506',
#  'with_mask_507',
#  'with_mask_508',
#  'with_mask_509',
#  'with_mask_510',
#  'with_mask_511',
#  'with_mask_512',
#  'with_mask_513',
#  'with_mask_514',
#  'with_mask_515',
#  'with_mask_516',
#  'with_mask_517',
#  'with_mask_518',
#  'with_mask_519',
#  'with_mask_520',
#  'with_mask_521',
#  'with_mask_522',
#  'with_mask_523',
#  'with_mask_524',
#  'with_mask_525',
#  'with_mask_526',
#  'with_mask_527',
#  'with_mask_528',
#  'with_mask_529',
#  'with_mask_530',
#  'with_mask_531',
#  'with_mask_532',
#  'with_mask_533',
#  'with_mask_534',
#  'with_mask_535',
#  'with_mask_536',
#  'with_mask_537',
#  'with_mask_538',
#  'with_mask_539',
#  'with_mask_540',
#  'with_mask_541',
#  'with_mask_542',
#  'with_mask_543',
#  'with_mask_544',
#  'with_mask_545',
#  'with_mask_546',
#  'with_mask_547',
#  'with_mask_548',
#  'with_mask_549',
#  'with_mask_550',
#  'with_mask_551',
#  'with_mask_552',
#  'with_mask_553',
#  'with_mask_554',
#  'with_mask_555',
#  'with_mask_556',
#  'with_mask_557',
#  'with_mask_558',
#  'with_mask_559',
#  'with_mask_560',
#  'with_mask_561',
#  'with_mask_562',
#  'with_mask_563',
#  'with_mask_564',
#  'with_mask_565',
#  'with_mask_566',
#  'with_mask_567',
#  'with_mask_568',
#  'with_mask_569',
#  'with_mask_570',
#  'with_mask_571',
#  'with_mask_572',
#  'with_mask_573',
#  'with_mask_574',
#  'with_mask_575',
#  'with_mask_576',
#  'with_mask_577',
#  'with_mask_578',
#  'with_mask_579',
#  'with_mask_580',
#  'with_mask_581',
#  'with_mask_582',
#  'with_mask_583',
#  'with_mask_584',
#  'with_mask_585',
#  'with_mask_586',
#  'with_mask_587',
#  'with_mask_588',
#  'with_mask_589',
#  'with_mask_590',
#  'with_mask_591',
#  'with_mask_592',
#  'with_mask_593',
#  'with_mask_594',
#  'with_mask_595',
#  'with_mask_596',
#  'with_mask_597',
#  'with_mask_598',
#  'with_mask_599',
#  'with_mask_600',
#  'with_mask_601',
#  'with_mask_602',
#  'with_mask_603',
#  'with_mask_604',
#  'with_mask_605',
#  'with_mask_606',
#  'with_mask_607',
#  'with_mask_608',
#  'with_mask_609',
#  'with_mask_610',
#  'with_mask_611',
#  'with_mask_612',
#  'with_mask_613',
#  'with_mask_614',
#  'with_mask_615',
#  'with_mask_616',
#  'with_mask_617',
#  'with_mask_618',
#  'with_mask_619',
#  'with_mask_620',
#  'with_mask_621',
#  'with_mask_622',
#  'with_mask_623',
#  'with_mask_624',
#  'with_mask_625',
#  'with_mask_626',
#  'with_mask_627',
#  'with_mask_628',
#  'with_mask_629',
#  'with_mask_630',
#  'with_mask_631',
#  'with_mask_632',
#  'with_mask_633',
#  'with_mask_634',
#  'with_mask_635',
#  'with_mask_636',
#  'with_mask_637',
#  'with_mask_638',
#  'with_mask_639',
#  'with_mask_640',
#  'with_mask_641',
#  'with_mask_642',
#  'with_mask_643',
#  'with_mask_644',
#  'with_mask_645',
#  'with_mask_646',
#  'with_mask_647',
#  'with_mask_648',
#  'with_mask_649',
#  'with_mask_650',
#  'with_mask_651',
#  'with_mask_652',
#  'with_mask_653',
#  'with_mask_654',
#  'with_mask_655',
#  'with_mask_656',
#  'with_mask_657',
#  'with_mask_658',
#  'with_mask_659',
#  'with_mask_660',
#  'with_mask_661',
#  'with_mask_662',
#  'with_mask_663',
#  'with_mask_664',
#  'with_mask_665',
#  'with_mask_666',
#  'with_mask_667',
#  'with_mask_668',
#  'with_mask_669',
#  'with_mask_670',
#  'with_mask_671',
#  'with_mask_672',
#  'with_mask_673',
#  'with_mask_674',
#  'with_mask_675',
#  'with_mask_676',
#  'with_mask_677',
#  'with_mask_678',
#  'with_mask_679',
#  'with_mask_680',
#  'with_mask_681',
#  'with_mask_682',
#  'with_mask_683',
#  'with_mask_684',
#  'with_mask_685',
#  'with_mask_686',
#  'with_mask_687',
#  'with_mask_688',
#  'with_mask_689',
#  'with_mask_690',
#  'with_mask_691',
#  'with_mask_692',
#  'with_mask_693',
#  'with_mask_694',
#  'with_mask_695',
#  'with_mask_696',
#  'with_mask_697',
#  'with_mask_698',
#  'with_mask_699',
#  'with_mask_700',
#  'with_mask_701',
#  'with_mask_702',
#  'with_mask_703',
#  'with_mask_704',
#  'with_mask_705',
#  'with_mask_706',
#  'with_mask_707',
#  'with_mask_708',
#  'with_mask_709',
#  'with_mask_710',
#  'with_mask_711',
#  'with_mask_712',
#  'with_mask_713',
#  'with_mask_714',
#  'with_mask_715',
#  'with_mask_716',
#  'with_mask_717',
#  'with_mask_718',
#  'with_mask_719',
#  'with_mask_720',
#  'with_mask_721',
#  'with_mask_722',
#  'with_mask_723',
#  'with_mask_724',
#  'with_mask_725',
#  'with_mask_726',
#  'with_mask_727',
#  'with_mask_728',
#  'with_mask_729',
#  'with_mask_730',
#  'with_mask_731',
#  'with_mask_732',
#  'with_mask_733',
#  'with_mask_734',
#  'with_mask_735',
#  'with_mask_736',
#  'with_mask_737',
#  'with_mask_738',
#  'with_mask_739',
#  'with_mask_740',
#  'with_mask_741',
#  'with_mask_742',
#  'with_mask_743',
#  'with_mask_744',
#  'with_mask_745',
#  'with_mask_746',
#  'with_mask_747',
#  'with_mask_748',
#  'with_mask_749',
#  'with_mask_750',
#  'with_mask_751',
#  'with_mask_752',
#  'with_mask_753',
#  'with_mask_754',
#  'with_mask_755',
#  'with_mask_756',
#  'with_mask_757',
#  'with_mask_758',
#  'with_mask_759',
#  'with_mask_760',
#  'with_mask_761',
#  'with_mask_762',
#  'with_mask_763',
#  'with_mask_764',
#  'with_mask_765',
#  'with_mask_766',
#  'with_mask_767',
#  'with_mask_768',
#  'with_mask_769',
#  'with_mask_770',
#  'with_mask_771',
#  'with_mask_772',
#  'with_mask_773',
#  'with_mask_774',
#  'with_mask_775',
#  'with_mask_776',
#  'with_mask_777',
#  'with_mask_778',
#  'with_mask_779',
#  'with_mask_780',
#  'with_mask_781',
#  'with_mask_782',
#  'with_mask_783',
#  'with_mask_784',
#  'with_mask_785',
#  'with_mask_786',
#  'with_mask_787',
#  'with_mask_788',
#  'with_mask_789',
#  'with_mask_790',
#  'with_mask_791',
#  'with_mask_792',
#  'with_mask_793',
#  'with_mask_794',
#  'with_mask_795',
#  'with_mask_796',
#  'with_mask_797',
#  'with_mask_798',
#  'with_mask_799',
#  'with_mask_800',
#  'with_mask_801',
#  'with_mask_802',
#  'with_mask_803',
#  'with_mask_804',
#  'with_mask_805',
#  'with_mask_806',
#  'with_mask_807',
#  'with_mask_808',
#  'with_mask_809',
#  'with_mask_810',
#  'with_mask_811',
#  'with_mask_812',
#  'with_mask_813',
#  'with_mask_814',
#  'with_mask_815',
#  'with_mask_816',
#  'with_mask_817',
#  'with_mask_818',
#  'with_mask_819',
#  'with_mask_820',
#  'with_mask_821',
#  'with_mask_822',
#  'with_mask_823',
#  'with_mask_824',
#  'with_mask_825',
#  'with_mask_826',
#  'with_mask_827',
#  'with_mask_828',
#  'with_mask_829',
#  'with_mask_830',
#  'with_mask_831',
#  'with_mask_832',
#  'with_mask_833',
#  'with_mask_834',
#  'with_mask_835',
#  'with_mask_836',
#  'with_mask_837',
#  'with_mask_838',
#  'with_mask_839',
#  'with_mask_840',
#  'with_mask_841',
#  'with_mask_842',
#  'with_mask_843',
#  'with_mask_844',
#  'with_mask_845',
#  'with_mask_846',
#  'with_mask_847',
#  'with_mask_848',
#  'with_mask_849',
#  'with_mask_850',
#  'with_mask_851',
#  'with_mask_852',
#  'with_mask_853',
#  'with_mask_854',
#  'with_mask_855',
#  'with_mask_856',
#  'with_mask_857',
#  'with_mask_858',
#  'with_mask_859',
#  'with_mask_860',
#  'with_mask_861',
#  'with_mask_862',
#  'with_mask_863',
#  'with_mask_864',
#  'with_mask_865',
#  'with_mask_866',
#  'with_mask_867',
#  'with_mask_868',
#  'with_mask_869',
#  'with_mask_870',
#  'with_mask_871',
#  'with_mask_872',
#  'with_mask_873',
#  'with_mask_874',
#  'with_mask_875',
#  'with_mask_876',
#  'with_mask_877',
#  'with_mask_878',
#  'with_mask_879',
#  'with_mask_880',
#  'with_mask_881',
#  'with_mask_882',
#  'with_mask_883',
#  'with_mask_884',
#  'with_mask_885',
#  'with_mask_886',
#  'with_mask_887',
#  'with_mask_888',
#  'with_mask_889',
#  'with_mask_890',
#  'with_mask_891',
#  'with_mask_892',
#  'with_mask_893',
#  'with_mask_894',
#  'with_mask_895',
#  'with_mask_896',
#  'with_mask_897',
#  'with_mask_898',
#  'with_mask_899',
#  'with_mask_900',
#  'with_mask_901',
#  'with_mask_902',
#  'with_mask_903',
#  'with_mask_904',
#  'with_mask_905',
#  'with_mask_906',
#  'with_mask_907',
#  'with_mask_908',
#  'with_mask_909',
#  'with_mask_910',
#  'with_mask_911',
#  'with_mask_912',
#  'with_mask_913',
#  'with_mask_914',
#  'with_mask_915',
#  'with_mask_916',
#  'with_mask_917',
#  'with_mask_918',
#  'with_mask_919',
#  'with_mask_920',
#  'with_mask_921',
#  'with_mask_922',
#  'with_mask_923',
#  'with_mask_924',
#  'with_mask_925',
#  'with_mask_926',
#  'with_mask_927',
#  'with_mask_928',
#  'with_mask_929',
#  'with_mask_930',
#  'with_mask_931',
#  'with_mask_932',
#  'with_mask_933',
#  'with_mask_934',
#  'with_mask_935',
#  'with_mask_936',
#  'with_mask_937',
#  'with_mask_938',
#  'with_mask_939',
#  'with_mask_940',
#  'with_mask_941',
#  'with_mask_942',
#  'with_mask_943',
#  'with_mask_944',
#  'with_mask_945',
#  'with_mask_946',
#  'with_mask_947',
#  'with_mask_948',
#  'with_mask_949',
#  'with_mask_950',
#  'with_mask_951',
#  'with_mask_952',
#  'with_mask_953',
#  'with_mask_954',
#  'with_mask_955',
#  'with_mask_956',
#  'with_mask_957',
#  'with_mask_958',
#  'with_mask_959',
#  'with_mask_960',
#  'with_mask_961',
#  'with_mask_962',
#  'with_mask_963',
#  'with_mask_964',
#  'with_mask_965',
#  'with_mask_966',
#  'with_mask_967',
#  'with_mask_968',
#  'with_mask_969',
#  'with_mask_970',
#  'with_mask_971',
#  'with_mask_972',
#  'with_mask_973',
#  'with_mask_974',
#  'with_mask_975',
#  'with_mask_976',
#  'with_mask_977',
#  'with_mask_978',
#  'with_mask_979',
#  'with_mask_980',
#  'with_mask_981',
#  'with_mask_982',
#  'with_mask_983',
#  'with_mask_984',
#  'with_mask_985',
#  'with_mask_986',
#  'with_mask_987',
#  'with_mask_988',
#  'with_mask_989',
#  'with_mask_990',
#  'with_mask_991',
#  'with_mask_992',
#  'with_mask_993',
#  'with_mask_994',
#  'with_mask_995',
#  'with_mask_996',
#  'with_mask_997',
#  'with_mask_998',
#  'with_mask_999',
#  ...]

# %% [markdown]
# Creating Dataframe for image names and their labels

# %%
labels_csv = pd.DataFrame(columns = ['ImageName', 'Label'])

labels_csv['ImageName'] = all_image_names

labels_csv['Label'][:5521] = 'with_mask'
labels_csv['Label'][5521:] = 'without_mask'

# %% [markdown]
# Plotting the Number of images in each Class

# %%
labels_csv['Label'].value_counts().plot.bar(figsize = (10, 7));

# %% [markdown]
# Storing the path of all images in a list

# %%
with_mask_filenames = sorted_alphanumeric(os.listdir(os.path.join(DATASET_DIR, 'with_mask')))
with_mask_filenames = [DATASET_DIR+'\\with_mask\\'+with_mask_filename for with_mask_filename in with_mask_filenames]

without_mask_filenames = sorted_alphanumeric(os.listdir(os.path.join(DATASET_DIR, 'without_mask')))
without_mask_filenames = [DATASET_DIR+'\\without_mask\\'+without_mask_filename for without_mask_filename in without_mask_filenames]

# %%
print("[INFO] loading images...")
imagePaths = with_mask_filenames + without_mask_filenames
imagePaths
# Out:
# [INFO] loading images...
# ['C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\0.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\1.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\2.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\3.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\4.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\5.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\6.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\7.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\8.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\9.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\10.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\11.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\12.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\13.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\14.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\15.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\16.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\17.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\18.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\19.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\20.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\21.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\22.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\23.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\24.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\25.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\26.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\27.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\28.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\29.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\30.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\31.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\32.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\33.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\34.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\35.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\36.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\37.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\38.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\39.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\40.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\41.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\42.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\43.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\44.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\45.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\46.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\47.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\48.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\49.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\50.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\51.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\52.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\53.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\54.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\55.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\56.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\57.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\58.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\59.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\60.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\61.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\62.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\63.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\64.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\65.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\66.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\67.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\68.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\69.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\70.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\71.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\72.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\73.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\74.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\75.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\76.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\77.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\78.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\79.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\80.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\81.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\82.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\83.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\84.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\85.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\86.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\87.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\88.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\89.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\90.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\91.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\92.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\93.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\94.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\95.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\96.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\97.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\98.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\99.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\100.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\101.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\102.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\103.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\104.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\105.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\106.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\107.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\108.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\109.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\110.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\111.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\112.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\113.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\114.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\115.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\116.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\117.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\118.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\119.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\120.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\121.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\122.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\123.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\124.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\125.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\126.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\127.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\128.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\129.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\130.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\131.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\132.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\133.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\134.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\135.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\136.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\137.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\138.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\139.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\140.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\141.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\142.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\143.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\144.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\145.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\146.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\147.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\148.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\149.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\150.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\151.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\152.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\153.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\154.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\155.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\156.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\157.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\158.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\159.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\160.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\161.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\162.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\163.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\164.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\165.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\166.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\167.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\168.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\169.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\170.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\171.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\172.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\173.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\174.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\175.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\176.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\177.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\178.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\179.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\180.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\181.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\182.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\183.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\184.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\185.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\186.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\187.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\188.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\189.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\190.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\191.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\192.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\193.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\194.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\195.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\196.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\197.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\198.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\199.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\200.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\201.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\202.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\203.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\204.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\205.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\206.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\207.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\208.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\209.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\210.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\211.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\212.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\213.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\214.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\215.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\216.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\217.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\218.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\219.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\220.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\221.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\222.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\223.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\224.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\225.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\226.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\227.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\228.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\229.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\230.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\231.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\232.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\233.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\234.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\235.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\236.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\237.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\238.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\239.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\240.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\241.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\242.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\243.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\244.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\245.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\246.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\247.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\248.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\249.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\250.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\251.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\252.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\253.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\254.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\255.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\256.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\257.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\258.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\259.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\260.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\261.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\262.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\263.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\264.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\265.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\266.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\267.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\268.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\269.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\270.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\271.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\272.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\273.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\274.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\275.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\276.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\277.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\278.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\279.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\280.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\281.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\282.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\283.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\284.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\285.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\286.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\287.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\288.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\289.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\290.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\291.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\292.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\293.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\294.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\295.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\296.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\297.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\298.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\299.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\300.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\301.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\302.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\303.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\304.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\305.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\306.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\307.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\308.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\309.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\310.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\311.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\312.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\313.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\314.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\315.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\316.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\317.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\318.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\319.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\320.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\321.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\322.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\323.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\324.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\325.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\326.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\327.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\328.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\329.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\330.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\331.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\332.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\333.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\334.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\335.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\336.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\337.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\338.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\339.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\340.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\341.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\342.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\343.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\344.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\345.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\346.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\347.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\348.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\349.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\350.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\351.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\352.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\353.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\354.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\355.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\356.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\357.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\358.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\359.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\360.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\361.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\362.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\363.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\364.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\365.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\366.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\367.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\368.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\369.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\370.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\371.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\372.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\373.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\374.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\375.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\376.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\377.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\378.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\379.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\380.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\381.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\382.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\383.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\384.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\385.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\386.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\387.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\388.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\389.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\390.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\391.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\392.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\393.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\394.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\395.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\396.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\397.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\398.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\399.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\400.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\401.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\402.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\403.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\404.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\405.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\406.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\407.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\408.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\409.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\410.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\411.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\412.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\413.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\414.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\415.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\416.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\417.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\418.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\419.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\420.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\421.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\422.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\423.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\424.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\425.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\426.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\427.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\428.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\429.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\430.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\431.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\432.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\433.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\434.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\435.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\436.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\437.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\438.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\439.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\440.jpg',
# ...
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\854.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\855.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\856.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\857.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\858.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\859.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\860.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\861.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\862.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\863.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\864.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\865.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\866.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\867.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\868.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\869.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\870.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\871.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\872.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\873.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\874.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\875.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\876.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\877.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\878.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\879.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\880.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\881.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\882.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\883.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\884.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\885.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\886.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\887.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\888.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\889.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\890.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\891.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\892.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\893.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\894.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\895.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\896.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\897.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\898.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\899.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\900.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\901.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\902.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\903.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\904.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\905.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\906.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\907.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\908.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\909.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\910.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\911.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\912.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\913.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\914.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\915.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\916.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\917.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\918.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\919.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\920.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\921.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\922.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\923.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\924.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\925.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\926.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\927.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\928.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\929.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\930.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\931.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\932.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\933.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\934.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\935.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\936.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\937.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\938.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\939.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\940.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\941.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\942.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\943.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\944.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\945.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\946.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\947.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\948.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\949.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\950.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\951.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\952.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\953.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\954.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\955.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\956.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\957.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\958.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\959.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\960.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\961.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\962.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\963.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\964.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\965.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\966.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\967.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\968.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\969.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\970.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\971.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\972.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\973.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\974.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\975.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\976.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\977.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\978.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\979.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\980.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\981.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\982.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\983.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\984.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\985.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\986.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\987.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\988.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\989.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\990.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\991.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\992.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\993.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\994.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\995.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\996.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\997.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\998.jpg',
#  'C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\Dataset\\with_mask\\999.jpg',
#  ...]

# %% [markdown]
# Visualizing images loaded using paths in above array

# %%
Image(imagePaths[20])

# %% [markdown]
# Converting label colums to numpy array

# %%
labels = labels_csv['Label'].to_numpy()
labels, len(labels)
# Out:
# (array(['with_mask', 'with_mask', 'with_mask', ..., 'without_mask',
#         'without_mask', 'without_mask'], dtype=object),
#  11042)

# %% [markdown]
# Finding the unique_labels out of labels list

# %%
unique_labels = np.unique(labels)
unique_labels
# Out:
# array(['with_mask', 'without_mask'], dtype=object)

# %% [markdown]
# Turning labels array to a boolean array

# %%
boolean_labels = [label == unique_labels for label in labels]
np.array(boolean_labels).shape
# Out:
# (11042, 2)

# %% [markdown]
# Visualizing Data Batches

# %%
x = imagePaths
y = boolean_labels
NUM_IMAGES = len(imagePaths)

# %%
np.random.seed(42)
xTrain, xValid, yTrain, yValid = train_test_split(x[:NUM_IMAGES],
                                                  y[:NUM_IMAGES],
                                                  test_size = 0.2)
len(xTrain), len(xValid)
# Out:
# (8833, 2209)

# %%
IMG_SIZE = 224
def preprocessor(image_path, image_size = IMG_SIZE):
    '''
    Takes an image file path and turns it into a tensor, normalizes and reshapes it
    '''
    # Read an image file
    image = tf.io.read_file(image_path)
    # Turn the jpg image into a tensor with 3 color channels
    image = tf.image.decode_jpeg(image, channels = 3)
    # Normalization, from 0-255 to 0-1
    image = tf.image.convert_image_dtype(image, tf.float32)
    # Resize the image to our desired values (60, 60)
    image = tf.image.resize(image, size = [IMG_SIZE, IMG_SIZE])
    return image

# %%
# Create a function to return (image, label)
def get_image_label(image_path, label):
    '''
    Takes image file path and the associated label as the imput and gives out
    the tuple of the two
    '''
    image = preprocessor(image_path)
    return image, label

# %%
# Creating a function to convert data into batches
def create_data_batches(x, y = None, batch_size = BATCH_SIZE, valid_data = False, test_data = False):
    '''
    Creates batches of Data out of images x and labels y pairs.
    Shuffles the training data but not validation data
    Also accepts test data as input (without labels)
    '''

    if test_data:
        print('Creating Test Data Batches!')

        # Turn filepaths (images) into a list of tensors/slices a big  tensor into smaller objects
        data = tf.data.Dataset.from_tensor_slices((tf.constant(x)))

        # Preprocess these sliced tensors(tensor for each image in file_names array) & batch them
        data_batch = data.map(preprocessor).batch(BATCH_SIZE)

        return data_batch

    elif valid_data:
        print('Creating Valid Data batches!')
        data = tf.data.Dataset.from_tensor_slices((tf.constant(x),
                                                   tf.constant(y)))
        data_batch = data.map(get_image_label).batch(BATCH_SIZE)
        return data_batch

    else:
        print('Creating Training data batches!')
        data = tf.data.Dataset.from_tensor_slices((tf.constant(x),
                                                   tf.constant(y)))
        # Shuffling pathnames and labels before mapping preprocessor function
        data = data.shuffle(buffer_size = len(x))

        data_batch = data.map(get_image_label).batch(BATCH_SIZE)

        return data_batch

# %%
# Creating training data batches
train_data = create_data_batches(xTrain, yTrain)
# Out:
# Creating Training data batches!

# %%
# Create a function for viewing images in a data batch
def show_25_images(images, labels):
    """
    Displays a plot of 25 images and their labels from a data batch.
    """
    # Setup the figure
    plt.figure(figsize=(10, 10))
    # Loop through 25 (for displaying 25 images)
    for i in range(25):
        # Create subplots (5 rows, 5 columns)
        ax = plt.subplot(5, 5, i+1)
        # Display an image 
        plt.imshow(images[i])
        # Add the image label as the title
        plt.title(unique_labels[labels[i].argmax()])
        # Turn the grid lines off
        plt.axis("off")

# %%
train_images, train_labels = next(train_data.as_numpy_iterator())

# %%
show_25_images(train_images, train_labels)

# %% [markdown]
# Loading all images from dataset directory and storing them in a list. Also storing the classes for each image in seperate list.

# %%
data = []
labels = []

for imagePath in imagePaths:
    # Extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]

    # load the input image (IMAGE_SIZExIMAGE_SIZE) and preprocess it
    image = load_img(imagePath, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    image = img_to_array(image)
    image = preprocess_input(image)

    data.append(image)
    labels.append(label)

# %% [markdown]
# Converting lists to numpy array for faster calculations

# %%
data = np.array(data, dtype="float32")
labels = np.array(labels)

# %% [markdown]
# Perform One-Hot Encoding on the labels

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
np.array(labels).shape
# Out:
# (11042, 2)

# %% [markdown]
# Splitting the data intp train and test set (80% data for training and 20%data for testing

# %%
(trainX, testX, trainY, testY) = train_test_split(data,
                                                  labels,
                                                  test_size=0.20,
                                                  stratify=labels,
                                                  random_state=42)

# %% [markdown]
# Define function for Image Augmentation, it also returns test and treain batches

# %%
aug = ImageDataGenerator(rotation_range=20,
                         zoom_range=0.15,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.15,
                         horizontal_flip=True,
                         fill_mode="nearest")

# %% [markdown]
# Function to create tensorboard callback

# %%
def create_tensorboard_callback():
    # Creating a log firectory for saving TensorBoard logs
    logdir = os.path.join('C:\\Users\\madan\\Projects\\SummerTraining\\Project\\Medical_Mask_Detection\\logs',
                          datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))
    return tf.keras.callbacks.TensorBoard(logdir)

# %% [markdown]
# Creating Early Stopping Callback to avoid overfitting

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'accuracy',
                                                  patience = 3)

# %% [markdown]
# Loading the base pretrained model of MobileNetV2

# %%
# load the MobileNetV2 network with the head layers
baseModel = MobileNetV2(weights="imagenet", include_top=False,
                        input_tensor=Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
                        input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3))

# %% [markdown]
# Constructing new head which will used on top of base model

# %%
# Construct new head for model which will be trained for our classification of masks
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# Place the Head FC model on top of the base model
model = Model(inputs=baseModel.input, outputs=headModel)

# Set all layers of base model to non trainable
for layer in baseModel.layers:
    layer.trainable = False

# %% [markdown]
# Compile the model

# %%
print("[INFO] Compiling model...")

opt = Adam(lr=LR, decay=LR / EPOCHS)

model.compile(loss="binary_crossentropy", optimizer=opt,
              metrics=["accuracy"]) # binary_crossentropy as ours is a binary classification
# Out:
# [INFO] Compiling model...

# %% [markdown]
# Train the head of the model

# %%
tensorboard = create_tensorboard_callback()

print("[INFO] Training head...")

H = model.fit(aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
              steps_per_epoch=len(trainX) // BATCH_SIZE,
              validation_data=(testX, testY),
              validation_steps=len(testX) // BATCH_SIZE,
              epochs=EPOCHS,
              callbacks = [tensorboard])
# Out:
# [INFO] Training head...
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 276 steps, validate on 2209 samples
# Epoch 1/30
# 276/276 [==============================] - 105s 379ms/step - loss: 0.3107 - accuracy: 0.8644 - val_loss: 0.3352 - val_accuracy: 0.8913
# Epoch 2/30
# 276/276 [==============================] - 108s 392ms/step - loss: 0.1502 - accuracy: 0.9452 - val_loss: 0.3708 - val_accuracy: 0.8918
# Epoch 3/30
# 276/276 [==============================] - 117s 425ms/step - loss: 0.1247 - accuracy: 0.9580 - val_loss: 0.4453 - val_accuracy: 0.8786
# Epoch 4/30
# 276/276 [==============================] - 120s 436ms/step - loss: 0.1018 - accuracy: 0.9642 - val_loss: 0.3111 - val_accuracy: 0.9185
# Epoch 5/30
# 276/276 [==============================] - 122s 443ms/step - loss: 0.0920 - accuracy: 0.9676 - val_loss: 0.3077 - val_accuracy: 0.9207
# Epoch 6/30
# 276/276 [==============================] - 119s 431ms/step - loss: 0.0879 - accuracy: 0.9691 - val_loss: 0.2720 - val_accuracy: 0.9280
# Epoch 7/30
# 276/276 [==============================] - 128s 464ms/step - loss: 0.0832 - accuracy: 0.9713 - val_loss: 0.4470 - val_accuracy: 0.8822
# Epoch 8/30
# 276/276 [==============================] - 119s 431ms/step - loss: 0.0812 - accuracy: 0.9703 - val_loss: 0.3224 - val_accuracy: 0.9185
# Epoch 9/30
# 276/276 [==============================] - 118s 426ms/step - loss: 0.0778 - accuracy: 0.9734 - val_loss: 0.3091 - val_accuracy: 0.9239
# Epoch 10/30
# 276/276 [==============================] - 115s 418ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.2506 - val_accuracy: 0.9321
# Epoch 11/30
# 276/276 [==============================] - 119s 431ms/step - loss: 0.0704 - accuracy: 0.9760 - val_loss: 0.3087 - val_accuracy: 0.9257
# Epoch 12/30
# 276/276 [==============================] - 114s 412ms/step - loss: 0.0666 - accuracy: 0.9763 - val_loss: 0.3154 - val_accuracy: 0.9244
# Epoch 13/30
# 276/276 [==============================] - 110s 398ms/step - loss: 0.0638 - accuracy: 0.9756 - val_loss: 0.3210 - val_accuracy: 0.9230
# Epoch 14/30
# 276/276 [==============================] - 237s 857ms/step - loss: 0.0572 - accuracy: 0.9798 - val_loss: 0.4355 - val_accuracy: 0.9049
# Epoch 15/30
# 276/276 [==============================] - 271s 983ms/step - loss: 0.0565 - accuracy: 0.9797 - val_loss: 0.3190 - val_accuracy: 0.9284
# Epoch 16/30
# 276/276 [==============================] - 266s 965ms/step - loss: 0.0593 - accuracy: 0.9799 - val_loss: 0.3933 - val_accuracy: 0.9112
# Epoch 17/30
# 276/276 [==============================] - 276s 999ms/step - loss: 0.0624 - accuracy: 0.9777 - val_loss: 0.4435 - val_accuracy: 0.8981
# Epoch 18/30
# 276/276 [==============================] - 287s 1s/step - loss: 0.0512 - accuracy: 0.9827 - val_loss: 0.3065 - val_accuracy: 0.9253
# Epoch 19/30
# 276/276 [==============================] - 269s 974ms/step - loss: 0.0513 - accuracy: 0.9805 - val_loss: 0.4328 - val_accuracy: 0.9062
# Epoch 20/30
# 276/276 [==============================] - 247s 895ms/step - loss: 0.0534 - accuracy: 0.9813 - val_loss: 0.3938 - val_accuracy: 0.9158
# Epoch 21/30
# 276/276 [==============================] - 256s 928ms/step - loss: 0.0471 - accuracy: 0.9849 - val_loss: 0.3766 - val_accuracy: 0.9203
# Epoch 22/30
# 276/276 [==============================] - 294s 1s/step - loss: 0.0497 - accuracy: 0.9836 - val_loss: 0.4375 - val_accuracy: 0.9085
# Epoch 23/30
# 276/276 [==============================] - 284s 1s/step - loss: 0.0443 - accuracy: 0.9842 - val_loss: 0.3872 - val_accuracy: 0.9167
# Epoch 24/30
# 276/276 [==============================] - 167s 604ms/step - loss: 0.0474 - accuracy: 0.9835 - val_loss: 0.5073 - val_accuracy: 0.8931
# Epoch 25/30
# 276/276 [==============================] - 120s 433ms/step - loss: 0.0481 - accuracy: 0.9836 - val_loss: 0.3113 - val_accuracy: 0.9248
# Epoch 26/30
# 276/276 [==============================] - 122s 442ms/step - loss: 0.0440 - accuracy: 0.9836 - val_loss: 0.3275 - val_accuracy: 0.9266
# Epoch 27/30
# 276/276 [==============================] - 129s 469ms/step - loss: 0.0431 - accuracy: 0.9838 - val_loss: 0.4467 - val_accuracy: 0.9044
# Epoch 28/30
# 276/276 [==============================] - 124s 450ms/step - loss: 0.0401 - accuracy: 0.9858 - val_loss: 0.4805 - val_accuracy: 0.9008
# Epoch 29/30
# 276/276 [==============================] - 123s 447ms/step - loss: 0.0357 - accuracy: 0.9874 - val_loss: 0.4027 - val_accuracy: 0.9230
# Epoch 30/30
# 276/276 [==============================] - 116s 420ms/step - loss: 0.0451 - accuracy: 0.9831 - val_loss: 0.3479 - val_accuracy: 0.9253

# %% [markdown]
# Making Predictions on test data and storing the model

# %%
# Make predictions
print("[INFO] Evaluating model...")
pred = model.predict(testX, batch_size=BATCH_SIZE)

# Get value of prediction with maximum probability
pred = np.argmax(pred, axis=1)

# show classification report
print(classification_report(testY.argmax(axis=1),
                            pred,
                            target_names=lb.classes_))

# Save model
print("[INFO] Saving model...")
model.save("maskdetector.model", save_format="h5")
# Out:
# [INFO] Evaluating model...
#               precision    recall  f1-score   support
#
#    with_mask       1.00      0.85      0.92      1104
# without_mask       0.87      1.00      0.93      1105
#
#     accuracy                           0.93      2209
#    macro avg       0.93      0.93      0.92      2209
# weighted avg       0.93      0.93      0.92      2209
#
# [INFO] Saving model...

# %% [markdown]
# # Visualizing Results

# %% [markdown]
# Plotting Training losses and accuracies together

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("lossandacuracy.png")

# %% [markdown]
# Plotting Training Accuracies

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.savefig("accuracy.png")

# %% [markdown]
# Plotting Training Losses

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="lower left")
plt.savefig("loss.png")

# %% [markdown]
# ROC curve ROC_AUC score

# %%
fpr, tpr, thresholds = roc_curve(pred, testY.argmax(axis=1)) 
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([-0.1, 1.0])
plt.ylim([-0.1, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.show()
plt.savefig("Roc_curve.png")

# %% [markdown]
# Confusion Matrix

# %%
results = confusion_matrix(testY.argmax(axis=1), pred)

print(results)
# Out:
# [[ 941  163]
#  [   2 1103]]

# %%
array = [[941,163],
         [2,1103]]
df_cm = pd.DataFrame(array, index = [i for i in classes],
                  columns = [i for i in classes])
sn.set(font_scale=2)
plt.figure(figsize = (10,10))
plt.title("Confusion Matrix")

sn.heatmap(df_cm, annot=True)
plt.savefig("cm.png")

# %% [markdown]
# # Classification on Static Images

# %% [markdown]
# Set path for face detector model files

# %%
PATH_FACEDETECTOR = input("Enter the path:") or "resnet_ssd_facedetector"
# Out:
# Enter the path:

# %% [markdown]
# Load face detector files and mask classification model

# %%
model = "maskdetector.model"
confidence_min = 0.5

# load face detector model from disk
print("[INFO] Loading face detector model...")
prototxtPath = os.path.sep.join([PATH_FACEDETECTOR, "deploy.prototxt"])
weightsPath = os.path.sep.join([PATH_FACEDETECTOR,"res10_300x300_ssd_iter_140000.caffemodel"])
net = cv2.dnn.readNet(prototxtPath, weightsPath)

# load the face mask detector model from disk
print("[INFO] Loading mask detector model...")
model = load_model(model)
# Out:
# [INFO] Loading face detector model...
# [INFO] Loading mask detector model...

# %% [markdown]
# Load image and construct blob

# %%
image = cv2.imread("testing\\test3.jpg")
original = image.copy()
(h, w) = image.shape[:2]

# Construct a blob from the image
blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300),
                             (104.0, 177.0, 123.0))

# %% [markdown]
# Detect Face, Make predictions and give output

# %%
print("[INFO] Detecting faces...")
net.setInput(blob)
detections = net.forward()


for i in range(0, detections.shape[2]):
    # Extract the confidence associated with the detection
    confidence = detections[0, 0, i, 2]

    if confidence > confidence_min:
        # Compute the (x, y)-coordinates of the bounding box 
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")

        # Ensure the bounding boxes fall within the dimensions of the frame
        (startX, startY) = (max(0, startX), max(0, startY))
        (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

        # Extract the face ROI, convert it from BGR to RGB channel, resize it to 224x224,
        # and preprocess it
        face = image[startY:endY, startX:endX]
        face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face = cv2.resize(face, (224, 224))
        face = img_to_array(face)
        face = preprocess_input(face)
        face = np.expand_dims(face, axis=0)

        # Make prediction
        (mask, withoutMask) = model.predict(face)[0]

        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

        # Include the probability in the label
        label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

        # Display the label and bounding box rectangle on the output frame
        cv2.putText(image, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(image, (startX, startY), (endX, endY), color, 10)

# Show the output image
cv2.imshow("Output", image)
# Save image
cv2.imwrite(r"C:\Users\madan\Projects\SummerTraining\Project\Medical_Mask_Detection\Output_test\test3.jpg", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [INFO] Detecting faces...

# %% [markdown]
# Visualize Predictions

# %%
images = [r"C:\Users\madan\Projects\SummerTraining\Project\Medical_Mask_Detection\Output_test\test"+str(i)+".jpg" for i in range(1, 13)]

# Setup the figure
plt.figure(figsize=(10, 10))
for i in range(1, 13):
    # Create subplots (5 rows, 5 columns)
    ax = plt.subplot(3, 4, i)
    # Display an image 
    plt.imshow(load_img(images[i-1], target_size=(400, 400)))
    # Add the image label as the title
    plt.title(images[i-1].split("\\")[-1])
    # Turn the grid lines off
    plt.axis("off")
plt.savefig("collage.png")

# %% [markdown]
# # Classification on Real time feed

# %% [markdown]
# Set path for face detector model files

# %%
PATH_FACEDETECTOR = input("Enter the path:") or "resnet_ssd_facedetector"
# Out:
# Enter the path:

# %% [markdown]
# Load face detector files and mask classification model

# %%
model = "maskdetector.model"
confidence_min = 0.5

# load face detector model from disk
print("[INFO] Loading face detector model...")
prototxtPath = os.path.sep.join([PATH_FACEDETECTOR, "deploy.prototxt"])
weightsPath = os.path.sep.join([PATH_FACEDETECTOR,"res10_300x300_ssd_iter_140000.caffemodel"])
faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)

# load the face mask detector model from disk
print("[INFO] Loading mask detector model...")
model = load_model(model)
# Out:
# [INFO] Loading face detector model...
# [INFO] Loading mask detector model...

# %%
def detect_and_predict_mask(frame, faceNet, maskNet):
    # Construct blob
    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300),
                                 (104.0, 177.0, 123.0))

    # Face Detction
    faceNet.setInput(blob)
    detections = faceNet.forward()

    # initialize list of faces, their locations and their predictions
    faces = []
    locs = []
    preds = []

    for i in range(0, detections.shape[2]):
        # Extract the confidence associated with the detection
        confidence = detections[0, 0, i, 2]

        if confidence > confidence_min:
            # compute the (x, y)-coordinates of the bounding box
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # ensure the bounding boxes fall within the dimensions of the frame
            (startX, startY) = (max(0, startX), max(0, startY))
            (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

            # Extract the face ROI, convert it from BGR to RGB channel, resize it to 224x224,
            # and preprocess it
            face = frame[startY:endY, startX:endX]
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)
            face = np.expand_dims(face, axis=0)

            # Add the face and bounding boxes to their respective lists
            faces.append(face)
            locs.append((startX, startY, endX, endY))

    # Make predictions when detected faces are more than one
    if len(faces) > 0:
        preds = maskNet.predict(faces)
        
    return (locs, preds)

# %% [markdown]
# Initialise Capturing real time video and make detections

# %%
# Initialize the video stream with little delay
print("[INFO] Start video stream...")
vs = VideoStream(src=0).start()
time.sleep(2.0)

while True:
    # Grab the frame from the threaded video stream and resize it
    frame = vs.read()
    frame = imutils.resize(frame, width=400)

    # Detect faces and make predictions
    (locs, preds) = detect_and_predict_mask(frame, faceNet, model)

    # Loop over the detected face locations and their corresponding locations
    for (box, pred) in zip(locs, preds):
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred

        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

        # Include the probability in the label
        label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

        # display the label and bounding box rectangle on the output frame
        cv2.putText(frame, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
        cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

    # Show the output frame
    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF
    # Press q for quitting
    if key == ord("q"):
        break

cv2.destroyAllWindows()
vs.stop()
# Out:
# [INFO] Start video stream...
